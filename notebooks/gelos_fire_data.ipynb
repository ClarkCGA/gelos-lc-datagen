# %% [markdown]
# Notebook: Terratorch Dataset and Data Modules for GELOS Fire

# %%
# TODO: Write the Custom Terratorch Dataset for the current version of the GELOS fire data
# https://ibm.github.io/terratorch/data/
# https://torchgeo.readthedocs.io/en/stable/tutorials/custom_raster_dataset.html

# %%
# TODO: Write the Custom Terratorch Data Module for the current version of the GELOS fire data

# %%
# TODO: Embedding extraction from models available in Terratorch.
# https://ibm.github.io/terratorch/generic_datasets/#terratorch.datasets.generic_pixel_wise_dataset.GenericNonGeoSegmentationDataset.__init__
